# %%
print("hello")
# Out:
# hello

# %%
# os,math,re
import os

# %%
os.getcwd()
# Out:
# 'c:\\Users\\RIya\\Desktop\\datascience\\os'

# %%
os.makedirs(r"hello\hii\i\dev")

# %%
os.getcwd()
# Out:
# 'c:\\Users\\RIya\\Desktop\\datascience\\os'

# %%
# os.chdir(r"C:\Users\RIya\Desktop\Bakery Project")

# %%
# os.getcwd()
# Out:
# 'C:\\Users\\RIya\\Desktop\\Bakery Project'

# %%
# os.mkdir("riya")

# %%
# os.rmdir("riya") # it is used for remove

# %%
# os.mkdir("riya") # it is used for create a file

# %%
# os.rmdir("riya")

# %%
# os.startfile(r"C:\Users\RIya\Desktop\datascience\os\osmoddule.ipynb")

# %%
os.mkdir("hello.txt")

# %%
os.chdir(r"C:\Users\RIya\Desktop\datascience\os")

# %%
os.mkdir("hello.txt")

# %%
os.path.isfile(r"C:\Users\RIya\Desktop\datascience\os\osmoddule.ipynb")# it is used to check file is peresent or not
# Out:
# True

# %%
os.path.isdir(r"C:\Users\RIya\Desktop\datascience\os\hello.txt") # it is used to check directory is peresent or not
# Out:
# True

# %%
os.path.exists(r"C:\Users\RIya\Desktop\datascience\python")
# Out:
# True

# %%
path1 =r' C:\Users\RIya\Desktop\new react app.zip\new react app/'
path2=r'firstReactApp\node_modules\.bin'
completepath=os.path.join(path1,path2)
print(os.listdir(completepath))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[42], line 7
#       3 completepath=os.path.join(path1,path2)
#       4
#       5
#       6
# ----> 7 print(os.listdir(completepath))
#
# OSError: [WinError 123] The filename, directory name, or volume label syntax is incorrect: ' C:\\Users\\RIya\\Desktop\\new react app.zip\\new react app/firstReactApp\\node_modules\\.bin'

# %%
os.path.getsize(r"C:\Users\RIya\Desktop\datascience\python")
# Out:
# 4096
