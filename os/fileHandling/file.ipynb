# %%
print("welcome")
# Out:
# welcome

# %%
# r is used for read the file
file=open("poiet.txt","r")
file.read()
# Out:
# 'Web development is an important field of technology that is used to create websites and web applications. It includes frontend development, which focuses on the design and user interface, and backend development, which handles the server and database operations. Technologies like HTML, CSS, JavaScript, and React are commonly used in web development. Today, web development plays a major role in education, business, entertainment, and communication.'

# %%
#readline is used to read the file line
file.readline(1)
# Out:
# ''

# %%
file.readlines()
# Out:
# []

# %%
with open("poiet.txt","r") as file:
    print(file.read())
# Out:
# Web development is an important field of technology that is used to create websites and web applications. It includes frontend development, which focuses on the design and user interface, and backend development, which handles the server and database operations. Technologies like HTML, CSS, JavaScript, and React are commonly used in web development. Today, web development plays a major role in education, business, entertainment, and communication.

# %%
file.close()

# %%
## write mode
file=open("poiet.txt","w")
file.write("hello, i am riya")
file.close()

# %%
file=open("poiet.txt","r")
file.read()
# Out:
# 'hello, i am riya'

# %%
file=open("riya1.txt","w")
file.write("hello")
file.close()

# %%
## append mode
file=open("poiet.txt","a")
file.write("hello")
file.close()

# %%
file=open("poiet.txt","r")
file.read()
# Out:
# 'hello, i am riyahello'

# %%
file=open("joshi.txt","w")
file.write("hello, i am riya")
file.close()

# %%
file=open("poiet.txt","r")
file.read()
# Out:
# 'hello, i am riya  hello'

# %%
file=open("poiet.txt","x")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 file=open("poiet.txt","x")
#
# FileExistsError: [Errno 17] File exists: 'poiet.txt'

# %% [markdown]
# ### Assignment
# input:-name,last_name,Address,date of birth,gender
#
# make file "name" name se and and show this all detais in  this file
